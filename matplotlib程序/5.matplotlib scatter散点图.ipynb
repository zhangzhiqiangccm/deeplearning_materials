# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.scatter(np.arange(5),np.arange(5))

# %%
x = np.random.normal(size=500)
y = np.random.normal(size=500)

plt.scatter(x,y,s=20,c='b',alpha=0.5)#alpha透明度

plt.xlim((-2,5))
plt.ylim((-2,2))

#隐藏坐标轴
plt.xticks(())
plt.yticks(())
# Out:
# ([], <a list of 0 Text yticklabel objects>)
