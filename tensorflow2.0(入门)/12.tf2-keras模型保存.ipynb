# %%
import tensorflow as tf
from tensorflow.keras.optimizers import SGD
# Out:
# /Users/qin/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# 载入数据集
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
print(x_train.shape, y_train.shape)

# 转独热编码one-hot
y_train = tf.keras.utils.to_categorical(y_train,num_classes=10)
y_test = tf.keras.utils.to_categorical(y_test,num_classes=10)

# 构建模型
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(10, activation='softmax')
])

# 训练模型
sgd = SGD(0.1)
model.compile(optimizer=sgd,
              loss='mse',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=10)

loss,metrics = model.evaluate(x_test, y_test)
# Out:
# (60000, 28, 28) (60000,)
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.0491 - accuracy: 0.7058
# Epoch 2/10
# 60000/60000 [==============================] - 2s 27us/sample - loss: 0.0256 - accuracy: 0.8574
# Epoch 3/10
# 60000/60000 [==============================] - 2s 30us/sample - loss: 0.0214 - accuracy: 0.8758
# Epoch 4/10
# 60000/60000 [==============================] - 2s 29us/sample - loss: 0.0194 - accuracy: 0.8852
# Epoch 5/10
# 60000/60000 [==============================] - 2s 28us/sample - loss: 0.0182 - accuracy: 0.8906s - loss: 0.0182 - accuracy
# Epoch 6/10
# 60000/60000 [==============================] - 2s 28us/sample - loss: 0.0173 - accuracy: 0.8950
# Epoch 7/10
# 60000/60000 [==============================] - 2s 28us/sample - loss: 0.0167 - accuracy: 0.8983s
# Epoch 8/10
# 60000/60000 [==============================] - 2s 30us/sample - loss: 0.0162 - accuracy: 0.9010
# Epoch 9/10
# 60000/60000 [==============================] - 2s 28us/sample - loss: 0.0158 - accuracy: 0.9028
# Epoch 10/10
# 60000/60000 [==============================] - 2s 29us/sample - loss: 0.0155 - accuracy: 0.9048s
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
# 保存模型
# HDF5文件，pip install h5py
model.save('keras_models/model.h5')
