# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# pip install keras
# import keras          # keras深度学习的框架
from tensorflow.keras.optimizers import SGD    # 推荐使用tensorflow.keras.框架
# Out:
# C:\Users\MeganLee\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
x_data = np.random.rand(100)
noise = np.random.normal(0,0.01,x_data.shape)
y_data = x_data*0.1 + 0.2 + noise

plt.scatter(x_data, y_data)
plt.show()

# %%
# 构建一个顺序模型（可一层一层的叠加）
model = tf.keras.Sequential()
# 在模型中添加一个全连接层（Dense）
model.add(tf.keras.layers.Dense(units=1,input_dim=1))
# sgd:Stochastic gradient descent，随机梯度下降法
# mse:Mean Squared Error，均方误差
model.compile(optimizer=SGD(0.1),loss='mse')

# 训练3001个批次
for step in range(3001):
    # 每次训练一个批次
    cost = model.train_on_batch(x_data,y_data)
    # 每500个batch打印一次cost值
    if step % 500 == 0:
        print('cost:',cost)

# x_data输入网络中，得到预测值y_pred
y_pred = model.predict(x_data)

# 显示随机点
plt.scatter(x_data,y_data)
# 显示预测结果
plt.plot(x_data,y_pred,'r-',lw=3)
plt.show()
# Out:
# cost: 0.0135789635
# cost: 0.000118186625
# cost: 0.000118160126
# cost: 0.00011816011
# cost: 0.00011816011
# cost: 0.00011816011
# cost: 0.00011816011
